# %% [markdown]
# # New Project

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Iteration 0

# %%
import requests
import pandas as pd
import re
import time
import os
from datetime import datetime


# API Configuration
API_KEY = "EJrUQCHuJ0IahRmYL00NZmEFar04efTqfRWx1EUe"  # Replace with your actual API key
SEARCH_URL = "https://api.govinfo.gov/search"
OUTPUT_FILE = f"house_bills_117th_congress_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
BILL_LIMIT = 50  # Limit for faster testing
BILL_TEXT_FOLDER = "bill_texts"
os.makedirs(BILL_TEXT_FOLDER, exist_ok=True)

# Step 1: Fetch House Bills (H.R.) from 117th Congress
def fetch_house_bills():
    headers = {"Content-Type": "application/json"}
    bills = []
    offsetMark = "*"

    print("\nFetching the first 10 House Bills from the 117th Congress...")

    while len(bills) < BILL_LIMIT:
        query_payload = {
            "query": "collection:BILLS congress:117 billtype:HR",
            "offsetMark": offsetMark,
            "pageSize": 50,  # Fetch in batches of 50
            "sort": "dateDesc",
            "format": "json"
        }

        response = requests.post(
            SEARCH_URL, json=query_payload, headers=headers, params={"api_key": API_KEY}
        )

        if response.status_code != 200:
            print(f"❌ Failed to fetch data: {response.status_code}")
            print(response.text)  # Print API error details
            return []

        data = response.json()
        bills.extend(data.get("results", []))

        # Stop once we have at least 10 bills
        if len(bills) >= BILL_LIMIT:
            break

        # Update offsetMark for next page
        offsetMark = data.get("offsetMark", None)
        if not offsetMark:
            break  # No more pages left

    print(f"✅ Fetched {len(bills[:BILL_LIMIT])} House Bills for testing.\n")
    return bills[:BILL_LIMIT]

# Step 2: Fetch detailed metadata from summary page
def fetch_bill_metadata(summary_url):
    headers = {"Content-Type": "application/json"}  
    try:
        response = requests.get(summary_url, headers=headers, params={"api_key": API_KEY})
        if response.status_code != 200:
            print(f"⚠️ Skipping metadata fetch (Status Code: {response.status_code}) for {summary_url}")
            return None  # Skip if the summary page is not available
        return response.json()
    except Exception as e:
        print(f"❌ Error fetching metadata from {summary_url}: {e}")
        return None

def download_bill_text(bill_id, bill_version):
    """Download and save the bill text if the version is 'ih'."""
    if bill_version != "ih":
        print(f"⏩ Skipping {bill_id}, not 'ih' version.")
        return
    
    text_url = f"https://www.govinfo.gov/content/pkg/BILLS-{bill_id}ih/html/BILLS-{bill_id}ih.htm"
    file_path = os.path.join(BILL_TEXT_FOLDER, f"{bill_id}ih.txt")
    print(f"📥 Downloading bill text for {bill_id}...")
    try:
        response = requests.get(text_url)
        if response.status_code == 200:
            with open(file_path, "w", encoding="utf-8") as file:
                file.write(response.text)
            print(f"✅ Downloaded and saved: {file_path}")
        else:
            print(f"⚠️ Failed to download {text_url} (Status: {response.status_code})")
    except Exception as e:
        print(f"❌ Error downloading {text_url}: {e}")

# Step 3: Extract metadata from the API response
def extract_name(member):
    """ Extract full name from the `name` field, with a fallback."""
    if "name" in member:
        if isinstance(member["name"], list) and member["name"]:
            return member["name"][0].get("authority-fnf", member["name"][0].get("fullName", "Unknown"))
        elif isinstance(member["name"], dict):
            return member["name"].get("authority-fnf", member["name"].get("fullName", "Unknown"))
    return "Unknown"

def download_bill_text(congress, bill_number):
    """Download and save the bill text if the version is 'ih'."""
    bill_id = f"BILLS-{congress}hr{bill_number}ih"
    text_url = f"https://www.govinfo.gov/content/pkg/{bill_id}/html/{bill_id}.htm"
    file_path = os.path.join(BILL_TEXT_FOLDER, f"{bill_id}.txt")
    print(f"📥 Downloading bill text for HR {bill_number} (Congress {congress})...")
    try:
        response = requests.get(text_url)
        if response.status_code == 200:
            with open(file_path, "w", encoding="utf-8") as file:
                file.write(response.text)
            print(f"✅ Downloaded and saved: {file_path}")
        else:
            print(f"⚠️ Failed to download {text_url} (Status: {response.status_code})")
    except Exception as e:
        print(f"❌ Error downloading {text_url}: {e}")

def extract_metadata(bills):
    extracted_data = []
    
    print(f"Extracting metadata from the first {len(bills)} bills...\n")

    for i, bill in enumerate(bills):
        package_id = bill.get("packageId", "").replace("BILLS-", "")  # Remove "BILLS-" prefix
        title = bill.get("title", "")
        last_modified = bill.get("lastModified", "")
        result_link = bill.get("resultLink", "")

        # Extract Bill Number (e.g., "117hr99ih" -> "HR 99")
        match = re.search(r"117hr(\d+)", package_id)
        bill_number = f"HR {match.group(1)}" if match else "Unknown"

        # Default values
        sponsors, cosponsors, committees, actions, session, bill_version, report_number = "None", "None", "None", "Not Available", "Unknown", "Unknown", "None"
        short_titles, is_private, branch, is_appropriation, collection_name, publisher, su_doc_class, date_issued, current_chamber, government_author1, government_author2, category = "None", "False", "Unknown", "False", "None", "None", "None", "Unknown", "Unknown", "None", "None", "None"

        if result_link:
            print(f"🔄 Fetching metadata for Bill {bill_number} ({i+1}/{len(bills)})...")
            bill_metadata = fetch_bill_metadata(result_link)
            if bill_metadata:
                # Extract Titles
                title = bill_metadata.get("title", title)
                short_titles = ", ".join([st.get("title", "Unknown") for st in bill_metadata.get("shortTitle", [])])

                # Extract other metadata
                session = bill_metadata.get("session", "Unknown")
                bill_version = bill_metadata.get("billVersion", "Unknown")
                is_private = bill_metadata.get("isPrivate", "False")
                branch = bill_metadata.get("branch", "Unknown")
                is_appropriation = bill_metadata.get("isAppropriation", "False")
                collection_name = bill_metadata.get("collectionName", "None")
                publisher = bill_metadata.get("publisher", "None")
                su_doc_class = bill_metadata.get("suDocClassNumber", "None")
                date_issued = bill_metadata.get("dateIssued", "Unknown")
                current_chamber = bill_metadata.get("currentChamber", "Unknown")
                government_author1 = bill_metadata.get("governmentAuthor1", "None")
                government_author2 = bill_metadata.get("governmentAuthor2", "None")
                category = bill_metadata.get("category", "None")

                # Extract Sponsors and Cosponsors
                members = bill_metadata.get("members", [])

                def extract_name(member):
                    """ Safely extract the full name from the `name` field in `members` """
                    if "name" in member and isinstance(member["name"], list):
                        return member["name"][0].get("authority-fnf", "Unknown")
                    return "Unknown"

                sponsors = ", ".join([extract_name(m) for m in members if m.get("role") == "SPONSOR"])
                cosponsors = ", ".join([extract_name(m) for m in members if m.get("role") == "COSPONSOR"])

                # Extract Committees
                committees_list = bill_metadata.get("committees", [])
                committees = ", ".join([c.get("committeeName", "Unknown") for c in committees_list if isinstance(c, dict)])

                # Extract Actions (Not available in this API)
                actions = "Not Available"

                # Extract Report Number if available
                other_identifier = bill_metadata.get("otherIdentifier", {})
                report_number = other_identifier.get("stock-number", "None")

                if bill_version == "ih":
                    download_bill_text(package_id, bill_version)

        # Append extracted data
        extracted_data.append({
            "Congress Number": 117,
            "Session": session,
            "Bill Number": bill_number,
            "Title": title,
            "Short Titles": short_titles,
            "Bill Version": bill_version,
            "Is Private": is_private,
            "Branch": branch,
            "Is Appropriation": is_appropriation,
            "Collection Name": collection_name,
            "Publisher": publisher,
            "SuDoc Class": su_doc_class,
            "Date Issued": date_issued,
            "Current Chamber": current_chamber,
            "Government Author 1": government_author1,
            "Government Author 2": government_author2,
            "Category": category,
            "Last Action Date": last_modified,
            "Report Number": report_number,
            "Bill Summary Link": result_link,
            "Sponsors": sponsors if sponsors else "None",
            "Cosponsors": cosponsors if cosponsors else "None",
            "Committees": committees if committees else "None",
            "Actions": actions
        })

        # Sleep to avoid rate limits
        time.sleep(0.5)  # Adjust if needed

    print(f"\n✅ Completed metadata extraction for {len(bills)} bills!\n")
    return extracted_data

# Main Execution
bills = fetch_house_bills()
if not bills:
    print("❌ No bills found or error in API call.")
else:
    metadata = extract_metadata(bills)
    
    # Save to CSV
    df = pd.DataFrame(metadata)
    if df.isnull().sum().sum() > 0:
        print("⚠️ Warning: Some fields have missing values. Review the dataset.")
    df.to_csv(OUTPUT_FILE, index=False)
    df.to_csv(OUTPUT_FILE, index=False)

    print(f"✅ Successfully saved metadata for {len(metadata)} bills to {OUTPUT_FILE} 🎉")
# Out:
# Fetching the first 10 House Bills from the 117th Congress...
# ✅ Fetched 50 House Bills for testing.
#
# Extracting metadata from the first 50 bills...
#
# 🔄 Fetching metadata for Bill HR 99 (1/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr99ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr99ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 999 (2/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr999ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr999ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 998 (3/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr998ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr998ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 997 (4/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr997ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr997ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 996 (5/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr996ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr996ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 995 (6/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr995ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr995ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 994 (7/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr994ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr994ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 993 (8/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr993ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr993ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 992 (9/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr992ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr992ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 991 (10/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr991ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr991ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 990 (11/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr990ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr990ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 98 (12/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr98ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr98ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 989 (13/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr989ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr989ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 988 (14/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr988ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr988ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 987 (15/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr987ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr987ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 986 (16/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr986ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr986ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 985 (17/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr985ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr985ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 984 (18/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr984ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr984ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 983 (19/50)...
# 🔄 Fetching metadata for Bill HR 983 (20/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr983ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr983ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 983 (21/50)...
# 🔄 Fetching metadata for Bill HR 982 (22/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr982ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr982ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 981 (23/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr981ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr981ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 980 (24/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr980ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr980ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 97 (25/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr97ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr97ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 979 (26/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr979ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr979ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 978 (27/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr978ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr978ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 977 (28/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr977ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr977ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 976 (29/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr976ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr976ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 975 (30/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr975ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr975ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 974 (31/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr974ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr974ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 973 (32/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr973ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr973ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 972 (33/50)...
# 🔄 Fetching metadata for Bill HR 972 (34/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr972ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr972ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 971 (35/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr971ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr971ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 970 (36/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr970ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr970ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9709 (37/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9709ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9709ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9708 (38/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9708ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9708ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9707 (39/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9707ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9707ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9706 (40/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9706ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9706ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9705 (41/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9705ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9705ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9704 (42/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9704ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9704ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9703 (43/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9703ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9703ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9702 (44/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9702ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9702ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9701 (45/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9701ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9701ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9700 (46/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9700ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9700ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 96 (47/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr96ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr96ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 969 (48/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr969ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr969ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9699 (49/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9699ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9699ihhrihih.txt
# 🔄 Fetching metadata for Bill HR 9698 (50/50)...
# 📥 Downloading bill text for HR ih (Congress 117hr9698ih)...
# ✅ Downloaded and saved: bill_texts\BILLS-117hr9698ihhrihih.txt
#
# ✅ Completed metadata extraction for 50 bills!
#
# ✅ Successfully saved metadata for 50 bills to house_bills_117th_congress_20250224_101446.csv 🎉

# %% [markdown]
# ### Iteration 1

# %%
import requests
import json

# API Configuration
API_KEY = "EJrUQCHuJ0IahRmYL00NZmEFar04efTqfRWx1EUe"  # Replace with your actual API key
SEARCH_URL = "https://api.govinfo.gov/search"

# Fetch a single bill for debugging
def fetch_single_bill():
    headers = {"Content-Type": "application/json"}
    query_payload = {
        "query": "collection:BILLS congress:117 billtype:HR",
        "offsetMark": "*",  # First request should use "*"
        "pageSize": 1,  # Fetch only one bill for inspection
        "sort": "dateDesc",
        "format": "json"
    }

    response = requests.post(
        SEARCH_URL, json=query_payload, headers=headers, params={"api_key": API_KEY}
    )

    if response.status_code != 200:
        print(f"Failed to fetch data: {response.status_code}")
        print(response.text)  # Print API error details
        return None

    return response.json()

# Run the request and print the raw response
raw_api_response = fetch_single_bill()
print(json.dumps(raw_api_response, indent=4))  # Pretty-print JSON
# Out:
# {
#     "results": [
#         {
#             "title": "Citizen Legislature Anti-Corruption Reform of Congress Act; CLEAN Congress Act",
#             "packageId": "BILLS-117hr99ih",
#             "granuleId": null,
#             "lastModified": "2024-06-06T19:38:38Z",
#             "governmentAuthor": [
#                 "Congress",
#                 "House of Representatives"
#             ],
#             "dateIssued": "2021-01-04",
#             "collectionCode": "BILLS",
#             "resultLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/summary",
#             "dateIngested": "2021-01-20",
#             "download": {
#                 "premisLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/premis",
#                 "xmlLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/xml",
#                 "txtLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/htm",
#                 "zipLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/zip",
#                 "modsLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/mods",
#                 "pdfLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/pdf"
#             },
#             "relatedLink": "https://api.govinfo.gov/related/BILLS-117hr99ih"
#         }
#     ],
#     "offsetMark": "AoEvQklMTFMtMTE3aHI5OWlo",
#     "count": 11931
# }

# %% [markdown]
# # Iteration 2

# %%
import requests
import json

# Replace this with an actual Bill Summary Link from the CSV
TEST_BILL_SUMMARY_URL = "https://api.govinfo.gov/packages/BILLS-117hr99ih/summary"
API_KEY = "EJrUQCHuJ0IahRmYL00NZmEFar04efTqfRWx1EUe"  # Replace with your API key

def fetch_and_print_summary(url):
    headers = {"Content-Type": "application/json"}
    
    response = requests.get(url, headers=headers, params={"api_key": API_KEY})
    
    if response.status_code != 200:
        print(f"❌ Failed to fetch summary data (Status Code: {response.status_code})")
        print(response.text)
        return

    bill_data = response.json()
    
    # Pretty-print the JSON response
    print(json.dumps(bill_data, indent=4))

# Run the test function
fetch_and_print_summary(TEST_BILL_SUMMARY_URL)
# Out:
# {
#     "originChamber": "HOUSE",
#     "congress": "117",
#     "session": "1",
#     "detailsLink": "https://www.govinfo.gov/app/details/BILLS-117hr99ih",
#     "shortTitle": [
#         {
#             "type": "measure",
#             "title": "Citizen Legislature Anti-Corruption Reform of Congress Act"
#         },
#         {
#             "type": "measure",
#             "title": "CLEAN Congress Act"
#         }
#     ],
#     "isPrivate": "false",
#     "title": "To prohibit a single bill or joint resolution presented by Congress to the President from containing multiple subjects and to require the equal application of laws to Members of Congress.",
#     "branch": "legislative",
#     "isAppropriation": "false",
#     "collectionName": "Congressional Bills",
#     "download": {
#         "premisLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/premis",
#         "xmlLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/xml",
#         "txtLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/htm",
#         "zipLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/zip",
#         "modsLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/mods",
#         "pdfLink": "https://api.govinfo.gov/packages/BILLS-117hr99ih/pdf"
#     },
#     "pages": "3",
#     "related": {
#         "billStatusLink": "https://api.govinfo.gov/packages/BILLSTATUS-117hr99/xml"
#     },
#     "relatedLink": "https://api.govinfo.gov/related/BILLS-117hr99ih",
#     "members": [
#         {
#             "role": "SPONSOR",
#             "chamber": "H",
#             "congress": "117",
#             "bioGuideId": "F000466",
#             "name": [
#                 {
#                     "authority-lnf": "Fitzpatrick, Brian K.",
#                     "authority-other": "Mr. Brian Fitzpatrick",
#                     "parsed": "Mr. Fitzpatrick",
#                     "authority-fnf": "Brian K. Fitzpatrick"
#                 }
#             ],
#             "memberName": "Fitzpatrick, Brian K.",
#             "state": "PA",
#             "party": "R"
#         },
#         {
#             "role": "COSPONSOR",
#             "chamber": "H",
#             "congress": "117",
#             "bioGuideId": "G000579",
#             "name": [
#                 {
#                     "authority-lnf": "Gallagher, Mike",
#                     "parsed": "Mr. Gallagher",
#                     "authority-fnf": "Mike Gallagher"
#                 }
#             ],
#             "memberName": "Gallagher, Mike",
#             "state": "WI",
#             "party": "R"
#         }
#     ],
#     "suDocClassNumber": "Y 1.6:, Y 1.4/6:",
#     "dateIssued": "2021-01-04",
#     "currentChamber": "HOUSE",
#     "billVersion": "ih",
#     "billType": "hr",
#     "packageId": "BILLS-117hr99ih",
#     "committees": [
#         {
#             "authorityId": "hsju00",
#             "chamber": "H",
#             "committeeName": "Committee on the Judiciary",
#             "type": "S"
#         }
#     ],
#     "collectionCode": "BILLS",
#     "governmentAuthor2": "House of Representatives",
#     "governmentAuthor1": "Congress",
#     "publisher": "U.S. Government Publishing Office",
#     "docClass": "hr",
#     "lastModified": "2024-06-06T19:38:38Z",
#     "category": "Bills and Statutes",
#     "billNumber": "99",
#     "otherIdentifier": {
#         "migrated-doc-id": "f:h99_ih.txt",
#         "parent-ils-system-id": "000501532",
#         "child-ils-title": "House bills",
#         "parent-ils-title": "Congressional bills",
#         "child-ils-system-id": "000325573",
#         "stock-number": "021-610-00252-9"
#     }
# }
